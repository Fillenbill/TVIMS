# %%
import csv

with open('var_16_lognorm.csv', 'r') as f:
    reader = csv.reader(f)
    column = []
    summ = 0
    for row in reader:
        summ += float(row[0])
        column.append(float(row[0]))
    column.sort()
print(column)
print("summ vubork =", i)
print("vubork srednee =", i/300)
print("median =", (column[150] + column[151])/2)
# Out:
# [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1.902984,
# ...

# %%
import csv

with open('var_16_lognorm.csv', 'r') as f:
    reader = csv.reader(f)
    column = []
    summ = 0
    for row in reader:
        summ += float(row[0])
        column.append(float(row[0]))
    column.sort()
print(column)
print("summ vubork =", summ)
print("vubork srednee =", i/300)
print("median =", (column[150] + column[151])/2)
# Out:
# [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1.902984,
# ...

# %%
import csv

with open('var_16_lognorm.csv', 'r') as f:
    reader = csv.reader(f)
    column = []
    summ = 0
    for row in reader:
        summ += float(row[0])
        column.append(float(row[0]))
    column.sort()
print(column)
print("summ vubork =", summ)
print("vubork srednee =", i/300)
print("median =", (column[150] + column[151])/2)
# Out:
# [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1.902984,
# ...

# %%
with open('var_16_lognorm.csv', 'r') as f:
    reader = csv.reader(f)
    column = []
    summ = 0
    for row in reader:
        summ += float(row[0])
        column.append(float(row[0]))
    column.sort()
print(column)
print("summ vubork =", summ)
print("vubork srednee =", summ/300)
print("median =", (column[150] + column[151])/2)
# Out:
# [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1.902984,
# ...

# %%
import csv

with open('var_16_lognorm.csv', 'r') as f:
    reader = csv.reader(f)
    column = []
    summ = 0
    for row in reader:
        summ += float(row[0])
        column.append(float(row[0]))
    column.sort()
print(column)
print("summ vubork =", summ)
print("vubork srednee =", summ/300)
print("median =", (column[150] + column[151])/2)
# Out:
# [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1.902984,
# ...

# %%
# Out:
#   Cell In[8], line 38
#     variance = sum((x - mean)2 for x in sample) / (n if biased else n-1)
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import csv

with open('var_16_lognorm.csv', 'r') as f:
    reader = csv.reader(f)
    column = []
    summ = 0
    for row in reader:
        summ += float(row[0])
        column.append(float(row[0]))
    column.sort()
print(column)
print("summ vubork =", summ)
print("vubork srednee =", summ/300)
print("median =", (column[150] + column[151])/2)
# Out:
# [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1.902984,
# ...

# %%
import csv

with open('var_16_lognorm.csv', 'r') as f:
    reader = csv.reader(f)
    summ = 0
    for row in reader:
        summ += float(row[0])
    column.sort()
print(column)
print("summ vubork =", summ)
print("vubork srednee =", summ/300)
print("median =", (column[150] + column[151])/2)
# Out:
# [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1.902984,
# ...

# %%
import csv

def read_csv_file(filename):
    with open(filename, 'r') as f:
        reader = csv.reader(f)
        column = []
        for row in reader:
            column.append(float(row[0]))
        return column

def sample_sum(sample):
    return sum(sample)

def sample_mean(sample):
    return sum(sample) / len(sample)

def sample_median(sample):
    n = len(sample)
    if n % 2 == 0:
        sample.sort()
        return (sample[n//2] + sample[n//2+1]) / 2
    else:
        return sample[n//2]

def sample_mode(sample):
    freq_dict = {}
    for x in sample:
        freq_dict[x] = freq_dict.get(x, 0) + 1
    max_freq = max(freq_dict.values())
    if max_freq == 1:
        return 0
    else:
        most_common_num = [k for k, v in freq_dict.items() if v == max_freq]
        return most_common_num[0]

def sample_range(sample):
    return max(sample) - min(sample)

def sample_variance(sample, biased=True):
    n = len(sample)
    mean = sample_mean(sample)
    variance = sum((x - mean)**2 for x in sample) / (n if biased else n-1)
    return variance

def sample_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    moment = sum(x**k for x in sample) / n
    return moment

def sample_central_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    cent_moment = sum((x - mean)**k for x in sample) / n
    return cent_moment

if __name__ == "__main__":
    filename = "var_16_lognorm.csv"
    column = read_csv_file(filename)
    column.sort()
    print("Column:", column)
    print("\nSample Sum:", sample_sum(column))
    print("Sample Mean:", sample_mean(column))
    print("Sample Median:", sample_median(column))
    print("Sample Mode:", sample_mode(column))
    print("Sample Range:", sample_range(column))
    print("Biased Sample Variance:", sample_variance(column, biased=True))
    print("Unbiased Sample Variance:", sample_variance(column, biased=False))
    k = 3
    print(f"Sample {k}-th Moment:", sample_moment(column, k))
    print(f"Sample {k}-th Central Moment:", sample_central_moment(column, k))
# Out:
# Column: [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1
# ...

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

def empirical_cdf(data):
       return 1

def read_csv_file(filename):
    with open(filename, 'r') as f:
        reader = csv.reader(f)
        column = []
        for row in reader:
            column.append(float(row[0]))
        return column

def sample_sum(sample):
    return sum(sample)

def sample_mean(sample):
    return sum(sample) / len(sample)

def sample_median(sample):
    n = len(sample)
    if n % 2 == 0:
        sample.sort()
        return (sample[n//2] + sample[n//2+1]) / 2
    else:
        return sample[n//2]

def sample_mode(sample):
    freq_dict = {}
    for x in sample:
        freq_dict[x] = freq_dict.get(x, 0) + 1
    max_freq = max(freq_dict.values())
    if max_freq == 1:
        return 0
    else:
        most_common_num = [k for k, v in freq_dict.items() if v == max_freq]
        return most_common_num[0]

def sample_range(sample):
    return max(sample) - min(sample)

def sample_variance(sample, biased=True):
    n = len(sample)
    mean = sample_mean(sample)
    variance = sum((x - mean)**2 for x in sample) / (n if biased else n-1)
    return variance

def sample_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    moment = sum(x**k for x in sample) / n
    return moment

def sample_central_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    cent_moment = sum((x - mean)**k for x in sample) / n
    return cent_moment

if __name__ == "__main__":
    filename = "var_16_lognorm.csv"
    column = read_csv_file(filename)
    column.sort()
    print("Column:", column)
    print("\nSample Sum:", sample_sum(column))
    print("Sample Mean:", sample_mean(column))
    print("Sample Median:", sample_median(column))
    print("Sample Mode:", sample_mode(column))
    print("Sample Range:", sample_range(column))
    print("Biased Sample Variance:", sample_variance(column, biased=True))
    print("Unbiased Sample Variance:", sample_variance(column, biased=False))
    k = 3
    print(f"Sample {k}-th Moment:", sample_moment(column, k))
    print(f"Sample {k}-th Central Moment:", sample_central_moment(column, k))
   

     # Выводим значения на график
     # plt.plot(x_ecdf, y_ecdf)
    plt.show()
# Out:
# Column: [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1
# ...

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

def empirical_cdf(data):
    
       return 1
    
def read_csv_file(filename):
    with open(filename, 'r') as f:
        reader = csv.reader(f)
        column = []
        for row in reader:
            column.append(float(row[0]))
        return column

def sample_sum(sample):
    return sum(sample)

def sample_mean(sample):
    return sum(sample) / len(sample)

def sample_median(sample):
    n = len(sample)
    if n % 2 == 0:
        sample.sort()
        return (sample[n//2] + sample[n//2+1]) / 2
    else:
        return sample[n//2]

def sample_mode(sample):
    freq_dict = {}
    for x in sample:
        freq_dict[x] = freq_dict.get(x, 0) + 1
    max_freq = max(freq_dict.values())
    if max_freq == 1:
        return 0
    else:
        most_common_num = [k for k, v in freq_dict.items() if v == max_freq]
        return most_common_num[0]

def sample_range(sample):
    return max(sample) - min(sample)

def sample_variance(sample, biased=True):
    n = len(sample)
    mean = sample_mean(sample)
    variance = sum((x - mean)**2 for x in sample) / (n if biased else n-1)
    return variance

def sample_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    moment = sum(x**k for x in sample) / n
    return moment

def sample_central_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    cent_moment = sum((x - mean)**k for x in sample) / n
    return cent_moment


if __name__ == "__main__":
    filename = "var_16_lognorm.csv"
    column = read_csv_file(filename)
    column.sort()
    print("Column:", column)
    print("\nSample Sum:", sample_sum(column))
    print("Sample Mean:", sample_mean(column))
    print("Sample Median:", sample_median(column))
    print("Sample Mode:", sample_mode(column))
    print("Sample Range:", sample_range(column))
    print("Biased Sample Variance:", sample_variance(column, biased=True))
    print("Unbiased Sample Variance:", sample_variance(column, biased=False))
    k = 3
    print(f"Sample {k}-th Moment:", sample_moment(column, k))
    print(f"Sample {k}-th Central Moment:", sample_central_moment(column, k))
   

     # Выводим значения на график
     # plt.plot(x_ecdf, y_ecdf)
    plt.show()
# Out:
# Column: [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1
# ...

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]) + 2.118733)

# Ограничиваем данные по оси X до 180
data = [x for x in data if x <= 180]

# Разбиваем данные на 50 интервалов и строим гистограмму
plt.hist(data, bins=50, density=True)

# Строим график логнормального распределения
mu, sigma = np.log(np.mean(data)), np.sqrt(np.log(1 + np.var(data) / np.mean(data)2))
x = np.linspace(0, 180, 100)
pdf = np.exp(-(np.log(x) - mu)2 / (2 * sigma*2)) / (x sigma * np.sqrt(2 * np.pi))
plt.plot(x, pdf)

# Оформляем график
plt.title('Lognormal distribution')
plt.xlabel('Value')
plt.ylabel('Probability density')
plt.show()
# Out:
#   Cell In[5], line 19
#     mu, sigma = np.log(np.mean(data)), np.sqrt(np.log(1 + np.var(data) / np.mean(data)2))
#                                                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

def empirical_cdf(data):
    
       return 1
    
def read_csv_file(filename):
    with open(filename, 'r') as f:
        reader = csv.reader(f)
        column = []
        for row in reader:
            column.append(float(row[0]))
        return column

def sample_sum(sample):
    return sum(sample)

def sample_mean(sample):
    return sum(sample) / len(sample)

def sample_median(sample):
    n = len(sample)
    if n % 2 == 0:
        sample.sort()
        return (sample[n//2] + sample[n//2+1]) / 2
    else:
        return sample[n//2]

def sample_mode(sample):
    freq_dict = {}
    for x in sample:
        freq_dict[x] = freq_dict.get(x, 0) + 1
    max_freq = max(freq_dict.values())
    if max_freq == 1:
        return 0
    else:
        most_common_num = [k for k, v in freq_dict.items() if v == max_freq]
        return most_common_num[0]

def sample_range(sample):
    return max(sample) - min(sample)

def sample_variance(sample, biased=True):
    n = len(sample)
    mean = sample_mean(sample)
    variance = sum((x - mean)**2 for x in sample) / (n if biased else n-1)
    return variance

def sample_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    moment = sum(x**k for x in sample) / n
    return moment

def sample_central_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    cent_moment = sum((x - mean)**k for x in sample) / n
    return cent_moment


if __name__ == "__main__":
    filename = "var_16_lognorm.csv"
    column = read_csv_file(filename)
    column.sort()
    print("Column:", column)
    print("\nSample Sum:", sample_sum(column))
    print("Sample Mean:", sample_mean(column))
    print("Sample Median:", sample_median(column))
    print("Sample Mode:", sample_mode(column))
    print("Sample Range:", sample_range(column))
    print("Biased Sample Variance:", sample_variance(column, biased=True))
    print("Unbiased Sample Variance:", sample_variance(column, biased=False))
    k = 3
    print(f"Sample {k}-th Moment:", sample_moment(column, k))
    print(f"Sample {k}-th Central Moment:", sample_central_moment(column, k))
   

     # Выводим значения на график
     # plt.plot(x_ecdf, y_ecdf)
    plt.show()
# Out:
# Column: [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1
# ...

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]) + 2.118733)

# Ограничиваем данные по оси X до 180
data = [x for x in data if x <= 180]

# Разбиваем данные на 50 интервалов и строим гистограмму
plt.hist(data, bins=50, density=True)

# Строим график логнормального распределения
mu, sigma = np.log(np.mean(data)), np.sqrt(np.log(1 + np.var(data) / np.mean(data)2))
x = np.linspace(0, 180, 100)
pdf = np.exp(-(np.log(x) - mu)2 / (2 * sigma*2)) / (x sigma * np.sqrt(2 * np.pi))
plt.plot(x, pdf)

# Оформляем график
plt.title('Lognormal distribution')
plt.xlabel('Value')
plt.ylabel('Probability density')
plt.show()
# Out:
#   Cell In[7], line 19
#     mu, sigma = np.log(np.mean(data)), np.sqrt(np.log(1 + np.var(data) / np.mean(data)2))
#                                                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import csv

with open('var_16_lognorm.csv', 'r') as f:
    reader = csv.reader(f)
    column = []
    summ = 0
    for row in reader:
        summ += float(row[0])
        column.append(float(row[0]))
    column.sort()
print(column)
print("summ vubork =", i)
print("vubork srednee =", i/300)
print("median =", (column[150] + column[151])/2)
# Out:
# [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1.902984,
# ...

# %%
import csv

with open('var_16_lognorm.csv', 'r') as f:
    reader = csv.reader(f)
    column = []
    summ = 0
    for row in reader:
        summ += float(row[0])
        column.append(float(row[0]))
    column.sort()
print(column)
print("summ vubork =", i)
print("vubork srednee =", i/300)
print("median =", (column[150] + column[151])/2)
# Out:
# [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1.902984,
# ...

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]) + 2.118733)

# Ограничиваем данные по оси X до 180
data = [x for x in data if x <= 180]

# Функция расчета интегральной кривой
def calculate_cumulative(data):
    x, y = np.unique(sorted(data)), np.arange(1, len(np.unique(sorted(data))) + 1)
    return x, y/y[-1]

# Функция построения графика
def plot_cumulative(x, y, label):
    plt.plot(x, y, label=label)

# Разбиваем данные на 50 интервалов и строим гистограмму
plt.hist(data, bins=50, density=True)

# Строим интегральные кривые
np.random.seed(42)
sample_sizes = [200]
for sample_size in sample_sizes:
    sample = np.random.choice(data, sample_size)
    x, y = calculate_cumulative(sample)
    plot_cumulative(x, y, label=f'n={sample_size}')

# Оформляем график
plt.title('Lognormal distribution')
plt.xlabel('Value')
plt.ylabel('Cumulative probability')
plt.legend()
plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

def empirical_cdf(data):
    
       return 1
    
def read_csv_file(filename):
    with open(filename, 'r') as f:
        reader = csv.reader(f)
        column = []
        for row in reader:
            column.append(float(row[0]))
        return column

def sample_sum(sample):
    return sum(sample)

def sample_mean(sample):
    return sum(sample) / len(sample)

def sample_median(sample):
    n = len(sample)
    if n % 2 == 0:
        sample.sort()
        return (sample[n//2] + sample[n//2+1]) / 2
    else:
        return sample[n//2]

def sample_mode(sample):
    freq_dict = {}
    for x in sample:
        freq_dict[x] = freq_dict.get(x, 0) + 1
    max_freq = max(freq_dict.values())
    if max_freq == 1:
        return 0
    else:
        most_common_num = [k for k, v in freq_dict.items() if v == max_freq]
        return most_common_num[0]

def sample_range(sample):
    return max(sample) - min(sample)

def sample_variance(sample, biased=True):
    n = len(sample)
    mean = sample_mean(sample)
    variance = sum((x - mean)**2 for x in sample) / (n if biased else n-1)
    return variance

def sample_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    moment = sum(x**k for x in sample) / n
    return moment

def sample_central_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    cent_moment = sum((x - mean)**k for x in sample) / n
    return cent_moment


if __name__ == "__main__":
    filename = "var_16_lognorm.csv"
    column = read_csv_file(filename)
    column.sort()
    print("Column:", column)
    print("\nSample Sum:", sample_sum(column))
    print("Sample Mean:", sample_mean(column))
    print("Sample Median:", sample_median(column))
    print("Sample Mode:", sample_mode(column))
    print("Sample Range:", sample_range(column))
    print("Biased Sample Variance:", sample_variance(column, biased=True))
    print("Unbiased Sample Variance:", sample_variance(column, biased=False))
    k = 3
    print(f"Sample {k}-th Moment:", sample_moment(column, k))
    print(f"Sample {k}-th Central Moment:", sample_central_moment(column, k))
   

     # Выводим значения на график
     # plt.plot(x_ecdf, y_ecdf)
    plt.show()
# Out:
# Column: [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1
# ...

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

def empirical_cdf(data):
    
       return 1
    
def read_csv_file(filename):
    with open(filename, 'r') as f:
        reader = csv.reader(f)
        column = []
        for row in reader:
            column.append(float(row[0]))
        return column

def sample_sum(sample):
    return sum(sample)

def sample_mean(sample):
    return sum(sample) / len(sample)

def sample_median(sample):
    n = len(sample)
    if n % 2 == 0:
        sample.sort()
        return (sample[n//2] + sample[n//2+1]) / 2
    else:
        return sample[n//2]

def sample_mode(sample):
    freq_dict = {}
    for x in sample:
        freq_dict[x] = freq_dict.get(x, 0) + 1
    max_freq = max(freq_dict.values())
    if max_freq == 1:
        return 0
    else:
        most_common_num = [k for k, v in freq_dict.items() if v == max_freq]
        return most_common_num[0]

def sample_range(sample):
    return max(sample) - min(sample)

def sample_variance(sample, biased=True):
    n = len(sample)
    mean = sample_mean(sample)
    variance = sum((x - mean)**2 for x in sample) / (n if biased else n-1)
    return variance

def sample_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    moment = sum(x**k for x in sample) / n
    return moment

def sample_central_moment(sample, k):
    n = len(sample)
    mean = sample_mean(sample)
    cent_moment = sum((x - mean)**k for x in sample) / n
    return cent_moment


if __name__ == "__main__":
    filename = "var_16_lognorm.csv"
    column = read_csv_file(filename)
    column.sort()
    print("Column:", column)
    print("\nSample Sum:", sample_sum(column))
    print("Sample Mean:", sample_mean(column))
    print("Sample Median:", sample_median(column))
    print("Sample Mode:", sample_mode(column))
    print("Sample Range:", sample_range(column))
    print("Biased Sample Variance:", sample_variance(column, biased=True))
    print("Unbiased Sample Variance:", sample_variance(column, biased=False))
    k = 3
    print(f"Sample {k}-th Moment:", sample_moment(column, k))
    print(f"Sample {k}-th Central Moment:", sample_central_moment(column, k))
   

     # Выводим значения на график
     # plt.plot(x_ecdf, y_ecdf)
    plt.show()
# Out:
# Column: [-2.118733, -2.118408, -2.116372, -2.116114, -2.115895, -2.114842, -2.11356, -2.112854, -2.112662, -2.112381, -2.112102, -2.111881, -2.111182, -2.109836, -2.109779, -2.107821, -2.10775, -2.106194, -2.104532, -2.101371, -2.101251, -2.09781, -2.094885, -2.094478, -2.094226, -2.094166, -2.094015, -2.091491, -2.089973, -2.0886, -2.086106, -2.083796, -2.08176, -2.078094, -2.076904, -2.074659, -2.074121, -2.068692, -2.067678, -2.065187, -2.06283, -2.06164, -2.056782, -2.054657, -2.054383, -2.052648, -2.050821, -2.04804, -2.04795, -2.044436, -2.041355, -2.040253, -2.039176, -2.038734, -2.035237, -2.034851, -2.033251, -2.031376, -2.027827, -2.02678, -2.025548, -2.025388, -2.021719, -2.016055, -2.014266, -2.013543, -2.010161, -2.005753, -2.004451, -2.002147, -2.001336, -1.997167, -1.988526, -1.987398, -1.980862, -1.980399, -1.972529, -1.967966, -1.967384, -1.95689, -1.936049, -1.933511, -1.930901, -1.930493, -1.928578, -1.923086, -1.918947, -1.913696, -1.911287, -1.907319, -1.9055, -1
# ...

# %%
from scipy.stats import norm

n = 300
x_bar = 18.5229
sigma = 108.3813
confidence_level = 0.99

alpha = 1 - confidence_level
alpha_div_2 = alpha / 2

z = norm.ppf(1 - alpha_div_2)

C_j = sigma * z / (n ** 0.5)

lower_bound = x_bar - C_j
upper_bound = x_bar + C_j

print("Значение C_j:", C_j)
print("Интервал оценки для параметра theta: ({:.4f}, {:.4f})".format(lower_bound, upper_bound))
# Out:
# Значение C_j: 16.117987259771695
# Интервал оценки для параметра theta: (2.4049, 34.6409)

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Загрузим данные из файла
data = np.genfromtxt('var_16_lognorm.csv', delimiter=',')

# Создадим теоретическую функцию распределения с параметрами логнормального распределения
mu = 0  # Параметр смещения
sigma = 1  # Параметр формы
x = np.linspace(0, np.max(data), 1000)  # 1000 точек для построения графика

# Функция ошибок
def normal_cdf(x):
    return 0.5 * (1 + erf((x - mu) / (sigma * np.sqrt(2))))

# Построим график теоретической функции распределения
plt.plot(x, normal_cdf(x), label='Теоретическая Функция Распределения')
plt.hist(data, bins=30, density=True, alpha=0.5, label='Эмпирическая Функция Распределения')
plt.xlabel('Значение')
plt.ylabel('Вероятность')
plt.legend()
plt.title('Теоретическая и Эмпирическая Функции Распределения')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      15     return 0.5 * (1 + erf((x - mu) / (sigma * np.sqrt(2))))
#      17 # Построим график теоретической функции распределения
# ---> 18 plt.plot(x, normal_cdf(x), label='Теоретическая Функция Распределения')
#      19 plt.hist(data, bins=30, density=True, alpha=0.5, label='Эмпирическая Функция Распределения')
#      20 plt.xlabel('Значение')
#
# Cell In[1], line 15, in normal_cdf(x)
#      14 def normal_cdf(x):
# ---> 15     return 0.5 * (1 + erf((x - mu) / (sigma * np.sqrt(2))))
#
# NameError: name 'erf' is not defined

# %%
NameError                                 Traceback (most recent call last)
Cell In[1], line 18
     15     return 0.5 * (1 + erf((x - mu) / (sigma * np.sqrt(2))))
     17 # Построим график теоретической функции распределения
---> 18 plt.plot(x, normal_cdf(x), label='Теоретическая Функция Распределения')
     19 plt.hist(data, bins=30, density=True, alpha=0.5, label='Эмпирическая Функция Распределения')
     20 plt.xlabel('Значение')

Cell In[1], line 15, in normal_cdf(x)
     14 def normal_cdf(x):
---> 15     return 0.5 * (1 + erf((x - mu) / (sigma * np.sqrt(2))))

NameError: name 'erf' is not defined
# Out:
#   Cell In[2], line 1
#     NameError                                 Traceback (most recent call last)
#                                               ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.special import erf  # Импортируем функцию ошибок

# Загрузим данные из файла
data = np.genfromtxt('var_16_lognorm.csv', delimiter=',')

# Создадим теоретическую функцию распределения с параметрами логнормального распределения
mu = 0  # Параметр смещения
sigma = 1  # Параметр формы
x = np.linspace(0, np.max(data), 1000)  # 1000 точек для построения графика

# Функция ошибок
def normal_cdf(x):
    return 0.5 * (1 + erf((x - mu) / (sigma * np.sqrt(2))))

# Построим график теоретической функции распределения
plt.plot(x, normal_cdf(x), label='Теоретическая Функция Распределения')
plt.hist(data, bins=30, density=True, alpha=0.5, label='Эмпирическая Функция Распределения')
plt.xlabel('Значение')
plt.ylabel('Вероятность')
plt.legend()
plt.title('Теоретическая и Эмпирическая Функции Распределения')
plt.show()

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.special import erf
import pandas as pd

# Загрузим данные из эксель-файла
data = pd.read_excel('var_16_lognorm.csv', header=None)
data = data.iloc[:, 0].values  # Берем значения из первого столбца

# Создадим теоретическую функцию распределения с параметрами логнормального распределения
mu = 0  # Параметр смещения
sigma = 1  # Параметр формы
x = np.linspace(0, np.max(data), 1000)  # 1000 точек для построения графика

# Функция ошибок
def normal_cdf(x):
    return 0.5 * (1 + erf((x - mu) / (sigma * np.sqrt(2))))

# Построим график теоретической функции распределения
plt.plot(x, normal_cdf(x), label='Теоретическая Функция Распределения')
plt.hist(data, bins=30, density=True, alpha=0.5, label='Эмпирическая Функция Распределения')
plt.xlabel('Значение')
plt.ylabel('Вероятность')
plt.legend()
plt.title('Теоретическая и Эмпирическая Функции Распределения')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 8
#       5 import pandas as pd
#       7 # Загрузим данные из эксель-файла
# ----> 8 data = pd.read_excel('var_16_lognorm.csv', header=None)
#       9 data = data.iloc[:, 0].values  # Берем значения из первого столбца
#      11 # Создадим теоретическую функцию распределения с параметрами логнормального распределения
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# ...

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
from scipy.special import erf
import pandas as pd

# Загрузим данные из эксель-файла
data = pd.read_excel('var_16_lognorm.csv', header=None)
data = data.iloc[:, 0].values  # Берем значения из первого столбца

# Создадим теоретическую функцию распределения с параметрами логнормального распределения
mu = 0  # Параметр смещения
sigma = 1  # Параметр формы
x = np.linspace(0, np.max(data), 1000)  # 1000 точек для построения графика

# Функция ошибок
def normal_cdf(x):
    return 0.5 * (1 + erf((x - mu) / (sigma * np.sqrt(2))))

# Построим график теоретической функции распределения
plt.plot(x, normal_cdf(x), label='Теоретическая Функция Распределения')
plt.hist(data, bins=30, density=True, alpha=0.5, label='Эмпирическая Функция Распределения')
plt.xlabel('Значение')
plt.ylabel('Вероятность')
plt.legend()
plt.title('Теоретическая и Эмпирическая Функции Распределения')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       5 import pandas as pd
#       7 # Загрузим данные из эксель-файла
# ----> 8 data = pd.read_excel('var_16_lognorm.csv', header=None)
#       9 data = data.iloc[:, 0].values  # Берем значения из первого столбца
#      11 # Создадим теоретическую функцию распределения с параметрами логнормального распределения
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# ...

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]) + 2.118733)

# Ограничиваем данные по оси X до 180
data = [x for x in data if x <= 180]

# Функция расчета интегральной кривой
def calculate_cumulative(data):
    x, y = np.unique(sorted(data)), np.arange(1, len(np.unique(sorted(data))) + 1)
    return x, y/y[-1]

# Функция построения графика
def plot_cumulative(x, y, label):
    plt.plot(x, y, label=label)

# Разбиваем данные на 50 интервалов и строим гистограмму
plt.hist(data, bins=50, density=True)

# Строим интегральные кривые
np.random.seed(42)
sample_sizes = [10,100,200]
for sample_size in sample_sizes:
    sample = np.random.choice(data, sample_size)
    x, y = calculate_cumulative(sample)
    plot_cumulative(x, y, label=f'n={sample_size}')

# Определяем параметры распределения
s, loc, scale = lognorm.fit(data, floc=0)

# Вычисляем теоретическую функцию распределения
x = np.linspace(0, 180, 1000)
cdf = lognorm.cdf(x, s=s, loc=loc, scale=scale)

# Строим график теоретической функции распределения
plt.plot(x, cdf, label='Theoretical')

# Оформляем график
plt.title('Lognormal distribution')
plt.xlabel('Value')
plt.ylabel('Cumulative probability')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FitDataError                              Traceback (most recent call last)
# Cell In[7], line 37
#      34     plot_cumulative(x, y, label=f'n={sample_size}')
#      36 # Определяем параметры распределения
# ---> 37 s, loc, scale = lognorm.fit(data, floc=0)
#      39 # Вычисляем теоретическую функцию распределения
#      40 x = np.linspace(0, 180, 1000)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_continuous_distns.py:66, in _call_super_mom.<locals>.wrapper(self, *args, **kwds)
#      64     return super(type(self), self).fit(*args, **kwds)
#      65 else:
# ---> 66     return fun(self, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_continuous_distns.py:5702, in lognorm_gen.fit(self, data, *args, **kwds)
#    5700     data = data - floc
#    5701 if np.any(data <= 0):
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm

# Генерируем случайные параметры
mu = np.random.normal(0, 1)
sigma = np.random.uniform(0, 1)
scale = np.exp(mu)
s = sigma

# Определяем диапазон значений
x = np.linspace(0, 180, 1000)

# Вычисляем теоретическую функцию распределения
cdf = lognorm.cdf(x, s=s, scale=scale)

# Строим график
plt.plot(x, cdf, label='Theoretical')

# Добавляем оформление графика
plt.title('Lognormal distribution with random parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative probability')
plt.legend()
plt.show()

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import lognorm

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]) + 2.118733)

# Ограничиваем данные по оси X до 180
data = [x for x in data if x <= 180]

# Функция расчета интегральной кривой
def calculate_cumulative(data):
    x, y = np.unique(sorted(data)), np.arange(1, len(np.unique(sorted(data))) + 1)
    return x, y/y[-1]

# Функция построения графика
def plot_cumulative(x, y, label):
    plt.plot(x, y, label=label)

# Разбиваем данные на 50 интервалов и строим гистограмму
plt.hist(data, bins=50, density=True)

# Строим интегральные кривые
np.random.seed(42)
sample_sizes = [10,100,200]
for sample_size in sample_sizes:
    sample = np.random.choice(data, sample_size)
    x, y = calculate_cumulative(sample)
    plot_cumulative(x, y, label=f'n={sample_size}')

# Определяем параметры распределения
s, loc, scale = lognorm.fit(data, floc=0)

# Вычисляем теоретическую функцию распределения
x = np.linspace(0, 180, 1000)
cdf = lognorm.cdf(x, s=s, loc=loc, scale=scale)

# Строим график теоретической функции распределения
plt.plot(x, cdf, label='Theoretical')

# Оформляем график
plt.title('Lognormal distribution')
plt.xlabel('Value')
plt.ylabel('Cumulative probability')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FitDataError                              Traceback (most recent call last)
# Cell In[9], line 37
#      34     plot_cumulative(x, y, label=f'n={sample_size}')
#      36 # Определяем параметры распределения
# ---> 37 s, loc, scale = lognorm.fit(data, floc=0)
#      39 # Вычисляем теоретическую функцию распределения
#      40 x = np.linspace(0, 180, 1000)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_continuous_distns.py:66, in _call_super_mom.<locals>.wrapper(self, *args, **kwds)
#      64     return super(type(self), self).fit(*args, **kwds)
#      65 else:
# ---> 66     return fun(self, *args, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_continuous_distns.py:5702, in lognorm_gen.fit(self, data, *args, **kwds)
#    5700     data = data - floc
#    5701 if np.any(data <= 0):
# ...

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]) + 2.118733)

# Ограничиваем данные по оси X до 180
data = [x for x in data if x <= 180]

# Строим гистограмму полной выборки
plt.hist(data, bins=50, density=True)
plt.title('Histogram of Full Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# Строим график логнормального распределения для полной выборки
mu, sigma = np.log(np.mean(data)), np.sqrt(np.log(1 + np.var(data) / np.mean(data)**2))
x = np.linspace(0, 180, 100)
pdf = np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2)) / (x * sigma * np.sqrt(2 * np.pi))
plt.plot(x, pdf)
plt.title('Lognormal Distribution (Full Data)')
plt.xlabel('Value')
plt.ylabel('Probability density')
plt.show()

# Строим графики для случайных подвыборок
for sample_size in [10, 100, 200]:
    sample = np.random.choice(data, sample_size, replace=False)
    mu_sample, sigma_sample = np.log(np.mean(sample)), np.sqrt(np.log(1 + np.var(sample) / np.mean(sample)**2))
    pdf_sample = np.exp(-(np.log(x) - mu_sample)**2 / (2 * sigma_sample**2)) / (x * sigma_sample * np.sqrt(2 * np.pi))
    plt.plot(x, pdf_sample, label=f'n = {sample_size}')
plt.title('Lognormal Distribution (Random Samples)')
plt.xlabel('Value')
plt.ylabel('Probability density')
plt.legend()
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\3395995832.py:25: RuntimeWarning: divide by zero encountered in log
#   pdf = np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2)) / (x * sigma * np.sqrt(2 * np.pi))
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\3395995832.py:25: RuntimeWarning: invalid value encountered in divide
#   pdf = np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2)) / (x * sigma * np.sqrt(2 * np.pi))
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\3395995832.py:36: RuntimeWarning: divide by zero encountered in log
#   pdf_sample = np.exp(-(np.log(x) - mu_sample)**2 / (2 * sigma_sample**2)) / (x * sigma_sample * np.sqrt(2 * np.pi))
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\3395995832.py:36: RuntimeWarning: invalid value encountered in divide
#   pdf_sample = np.exp(-(np.log(x) - mu_sample)**2 / (2 * sigma_sample**2)) / (x * sigma_sample * np.sqrt(2 * np.pi))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

def plot_theoretical_cdf(data, loc, scale):
    # Ограничиваем данные по оси X до максимального значения в выборке
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)

    # Вычисляем теоретическую функцию распределения (CDF)
    cdf = 0.5 + 0.5 * np.erf((np.log(x) - np.log(loc)) / (np.sqrt(2) * scale))

    # Построение графика
    plt.plot(x, cdf, label='Theoretical CDF')
    plt.title('Theoretical CDF')
    plt.xlabel('Value')
    plt.ylabel('Cumulative Probability')
    plt.legend()
    plt.show()

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем параметры распределения
loc = 3.5
scale = 0.8

# Построение теоретической функции распределения
plot_theoretical_cdf(data, loc, scale)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 36
#      33 scale = 0.8
#      35 # Построение теоретической функции распределения
# ---> 36 plot_theoretical_cdf(data, loc, scale)
#
# Cell In[11], line 11, in plot_theoretical_cdf(data, loc, scale)
#       8 x = np.linspace(0, data_max, 100)
#      10 # Вычисляем теоретическую функцию распределения (CDF)
# ---> 11 cdf = 0.5 + 0.5 * np.erf((np.log(x) - np.log(loc)) / (np.sqrt(2) * scale))
#      13 # Построение графика
#      14 plt.plot(x, cdf, label='Theoretical CDF')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# ...

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erfc

def plot_theoretical_cdf(data, loc, scale):
    # Ограничиваем данные по оси X до максимального значения в выборке
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)

    # Вычисляем теоретическую функцию распределения (CDF)
    cdf = 0.5 + 0.5 * erfc((np.log(x) - np.log(loc)) / (np.sqrt(2) * scale))

    # Построение графика
    plt.plot(x, cdf, label='Theoretical CDF')
    plt.title('Theoretical CDF')
    plt.xlabel('Value')
    plt.ylabel('Cumulative Probability')
    plt.legend()
    plt.show()

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем параметры распределения
loc = 3.5
scale = 0.8

# Построение теоретической функции распределения
plot_theoretical_cdf(data, loc, scale)
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1718128804.py:12: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erfc((np.log(x) - np.log(loc)) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erfc

def plot_theoretical_cdf(data, loc, scale):
    # Ограничиваем данные по оси X до максимального значения в выборке
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)

    # Вычисляем теоретическую функцию распределения (CDF)
    cdf = 0.5 + 0.5 * erfc((np.log(x) - np.log(loc)) / (np.sqrt(2) * scale))

    # Построение графика
    plt.plot(x, cdf, label='Theoretical CDF')
    plt.title('Theoretical CDF')
    plt.xlabel('Value')
    plt.ylabel('Cumulative Probability')
    plt.legend()
    plt.show()

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем параметры распределения
loc = 3.5
scale = 0.8

# Построение теоретической функции распределения
plot_theoretical_cdf(data, loc, scale)
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1718128804.py:12: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erfc((np.log(x) - np.log(loc)) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erfc

def plot_theoretical_cdf(data, loc, scale):
    # Ограничиваем данные по оси X до максимального значения в выборке
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)

    # Вычисляем теоретическую функцию распределения (CDF)
    cdf = 0.5 + 0.5 * erfc((np.log(x) - np.log(loc)) / (np.sqrt(2) * scale))

    # Построение графика
    plt.plot(x, cdf, label='Theoretical CDF')
    plt.title('Theoretical CDF')
    plt.xlabel('Value')
    plt.ylabel('Cumulative Probability')
    plt.legend()
    plt.show()

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем параметры распределения
loc = 3.5
scale = 0.8

# Построение теоретической функции распределения
plot_theoretical_cdf(data, loc, scale)
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1718128804.py:12: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erfc((np.log(x) - np.log(loc)) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    # Ограничиваем данные по оси X до максимального значения в выборке
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)

    # Вычисляем теоретическую функцию распределения (CDF)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

    # Построение графика
    plt.plot(x, cdf, label='Theoretical CDF')
    plt.title('Theoretical CDF')
    plt.xlabel('Value')
    plt.ylabel('Cumulative Probability')
    plt.legend()
    plt.show()

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем параметры распределения
loc = 3 # Значение loc должно быть положительным
scale = 1


# Построение теоретической функции распределения
plot_theoretical_cdf(data, loc, scale)
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\4160807565.py:12: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 21)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1400250647.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 21)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1400250647.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 21)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1400250647.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 21)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1400250647.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 21)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1400250647.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 8)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1400250647.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 8)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\3964241937.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 15)  # Генерируем случайное значение для loc от 1 до 20
    scale = np.random.randint(1, 15)  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1530334508.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 15)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\697642700.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 10)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\355584752.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 10)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\2367984025.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 4

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(10, 6))
for _ in range(num_params):
    loc = np.random.randint(1, 10)  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\2367984025.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 1

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(5, 6))
for _ in range(num_params):
    loc = 0  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\1522269634.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

def plot_theoretical_cdf(data, loc, scale):
    data_max = np.max(data)
    x = np.linspace(0, data_max, 100)
    cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
    return x, cdf

# Считываем данные из файла
data = []
with open('var_16_lognorm.csv', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    for row in reader:
        data.append(float(row[0]))

# Ограничиваем данные по оси X до 200
data = [x for x in data if x <= 200]

# Задаем количество случайных параметров, которые мы хотим сгенерировать
num_params = 1

# Построение теоретической функции распределения для каждого набора параметров
plt.figure(figsize=(5, 6))
for _ in range(num_params):
    loc = 0  # Генерируем случайное значение для loc от 1 до 20
    scale = 1  # Генерируем случайное значение для scale от 1 до 20
    x, cdf = plot_theoretical_cdf(data, loc, scale)
    plt.plot(x, cdf, label=f'scale={scale}, loc={loc}')

plt.title('Theoretical CDF with Random Parameters')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Пользователь\AppData\Local\Temp\ipykernel_9380\3230795047.py:9: RuntimeWarning: divide by zero encountered in log
#   cdf = 0.5 + 0.5 * erf((np.log(x) - loc) / (np.sqrt(2) * scale))
